# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/tishamae19/Tisha-Mae/main/SALARY_DATA.csv')

# %%
print(df)
# Out:
#     Employee ID     Name  Age Department  Salary
# 0             1    Alice   45         Hr   54000
# 1             2      Bob   52         It   78000
# 2             3  Charlie   37    Finance   66000
# 3             4    David   28  Markiting   72000
# 4             5      Eva   41      Sales   85000
# 5             6    Frank   53         It   90000
# 6             7    Grace   32    Finance   62000
# 7             8    Henry   25         Hr   40000
# 8             9      Ivy   48      Sales   94000
# 9            10     Jack   39  Markiting   70000
# 10           11    Karen   29         It   65000
# 11           12      Leo   44    Finance   86000
# 12           13     Mona   33         Hr   47000
# 13           14     Nina   51      Sales   88000
# 14           15    Oscar   36  Markiting   56000

# %%
mean_salary = df['Salary'].mean

# %%
print(mean_salary)
# Out:
# <bound method Series.mean of 0     54000
# 1     78000
# 2     66000
# 3     72000
# 4     85000
# 5     90000
# 6     62000
# 7     40000
# 8     94000
# 9     70000
# 10    65000
# 11    86000
# 12    47000
# 13    88000
# 14    56000
# Name: Salary, dtype: int64>

# %%
median_salary = df['Salary'].median

# %%
print(median_salary)
# Out:
# <bound method Series.median of 0     54000
# 1     78000
# 2     66000
# 3     72000
# 4     85000
# 5     90000
# 6     62000
# 7     40000
# 8     94000
# 9     70000
# 10    65000
# 11    86000
# 12    47000
# 13    88000
# 14    56000
# Name: Salary, dtype: int64>

# %%
std_salary = df['Salary'].std()

# %%
print(std_salary)
# Out:
# 16549.4928709527

# %%
total_salary_expediture = df['Salary'].sum()

# %%
print(total_salary_expediture)
# Out:
# 1053000
